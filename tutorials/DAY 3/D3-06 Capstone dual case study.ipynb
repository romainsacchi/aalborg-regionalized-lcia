# %% [markdown]
# # D3-06 Capstone dual case study
#
# Run this notebook in the `bw` environment unless noted otherwise.

# %% [markdown]
# ## Learning goals
#
# - Define a transparent comparison with your team.
# - Reuse the scenario-LCIA and inventory-flow workflows from Day 3.
# - Test how one changed assumption affects the interpretation.
# - Separate numerical evidence, assumptions, limitations, and recommendations.
# - Communicate the result in a concise five-minute report.

# %% [markdown]
# ## Concept
#
# Capstone combines Day 2 and Day 3 methods into a final applied exercise. The objective is not to produce the largest model; it is to make a reproducible comparison and explain what the result does and does not support.
#
# Reuse working objects, tables, or figures from `D3-02` to `D3-05`. Instructors will help diagnose blockers, but teams should choose and justify their own comparison.

# %% [markdown]
# ## Team roles and timing
#
# Work in teams of three or four. Assign these roles before opening the exercise cells:
#
# - **Driver:** operates the notebook and narrates each change.
# - **Navigator:** checks the workflow and proposes the next step.
# - **Reviewer:** checks units, assumptions, reproducibility, and interpretation.
# - **Reporter:** records decisions and prepares the five-minute report.
#
# In a team of three, combine reviewer and reporter. Rotate driver and navigator between Tasks 1 and 2.
#
# Suggested timing: 10 minutes for roles and case selection, 45 minutes for Task 1, 45 minutes for Task 2, and 10 minutes for synthesis. Team reports begin at 17:20.

# %%
import pandas as pd

capstone_report = pd.DataFrame([
    {
        'section': 'Task 1 - scenario LCIA',
        'comparison': '',
        'method / indicator': '',
        'result or evidence': '',
        'interpretation': '',
    },
    {
        'section': 'Task 2 - inventory flow',
        'comparison': '',
        'method / indicator': '',
        'result or evidence': '',
        'interpretation': '',
    },
    {
        'section': 'Robustness check',
        'comparison': '',
        'method / indicator': '',
        'result or evidence': '',
        'interpretation': '',
    },
])
capstone_report

# %% [markdown]
# ## Exercise
#
# ### Task 1 - Scenario LCIA
#
# 1. Select one activity and two parameter settings, scenarios, or time points from `D3-02` or `D3-03`.
# 2. State the functional unit, LCIA method, changed parameter, and expected direction before running the calculation.
# 3. Produce one comparison table or figure.
# 4. Explain the main result and one reason it could change.
#
# ### Task 2 - Inventory flow assessment
#
# 1. Select two routes, activities, or tracked materials from `D3-04` or `D3-05`.
# 2. State the tracked flow, factor source, and comparison basis.
# 3. Identify the dominant contribution or vulnerability signal.
# 4. Explain whether the result supports a decision or only indicates where further investigation is needed.
#
# ### Robustness check
#
# Change one assumption, parameter, activity, location, or factor and rerun the relevant comparison. Record whether the ranking or interpretation changes.
#
# ### Required team outputs
#
# - a completed `capstone_report`;
# - one table or figure for each task;
# - three limitations or cautions;
# - one recommended next analysis step;
# - a five-minute report in which every team member contributes.

# %%
# TODO: Complete this record as your team works.
team_submission = {
    'team_name': '',
    'members_and_roles': {},
    'three_limitations': [],
    'recommended_next_step': '',
    'reporter': '',
}

# Fill the rows of `capstone_report` with your comparisons and evidence.
display(capstone_report)
team_submission

# %% [markdown]
# ## Completion rubric
#
# A strong submission does all of the following:
#
# - **Reproducible:** identifies the project state, activity or route, functional unit, and method.
# - **Transparent:** records the changed assumption and factor or data source.
# - **Evidence-based:** includes readable tables or figures tied to the interpretation.
# - **Critical:** distinguishes a numerical result from its limitations and decision relevance.
# - **Collaborative:** uses the assigned roles and gives each team member a part in the report.

# %%
quality_check = pd.DataFrame([
    {'criterion': 'Functional unit and comparison are stated', 'complete': False},
    {'criterion': 'Method, factor source, and changed assumption are recorded', 'complete': False},
    {'criterion': 'Each task has a table or figure', 'complete': False},
    {'criterion': 'Interpretation follows from the evidence', 'complete': False},
    {'criterion': 'Three limitations and one next step are documented', 'complete': False},
])
quality_check
