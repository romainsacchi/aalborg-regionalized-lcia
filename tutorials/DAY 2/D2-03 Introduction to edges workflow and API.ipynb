# %% [markdown]
# # D2-03 Introduction to `edges` workflow and API
#
# This notebook introduces the basic `edges` workflow through two small JSON methods: one with direct matching only, and one with location-specific characterization factors.

# %% [markdown]
# ## Learning goals
#
# After this notebook, you should be able to:
#
# - inspect bundled `edges` JSON method files
# - run a simple `EdgeLCIA` workflow with direct exchange matching
# - understand how location constraints change the mapping process
# - use the main helper functions for aggregate, dynamic, contained, and global fallback mappings
# - inspect the exchange-level CFs actually applied in a calculation

# %% [markdown]
# ## Background references
#
# - Sacchi, R., Menacho, A. H., Seitfudem, G., Agez, M., Schlesinger-Martinat, J., Koyamparambath, A., Saldivar, J. S., Loubet, P., & Bauer, C. (2025). Contextual LCIA without the overhead: an exchange-based framework for flexible impact assessment. *The International Journal of Life Cycle Assessment, 30*(12), 3087-3101. https://doi.org/10.1007/s11367-025-02551-7
# - Brightway documentation: https://docs.brightway.dev/
# - Bundled `edges` JSON examples in `tutorials/DAY 2/assets/edges_examples/`

# %% [markdown]
# ## 1) Locate the JSON examples used in this notebook
#
# These two files are bundled with the course repository and are used directly below:
#
# - `lcia_example_1.json`: direct exchange matching
# - `lcia_example_2.json`: location-specific characterization with spatial helper mappings
#
# The workflow cells below use the course Brightway project `aalborg-rlcia-2026` and its imported `bafu` database.

# %%
import json
from pathlib import Path

import bw2data as bd
import pandas as pd
from IPython.display import display
from edges import EdgeLCIA, get_available_methods

example_1_path = Path('assets/edges_examples/lcia_example_1.json')
example_2_path = Path('assets/edges_examples/lcia_example_2.json')

# %% [markdown]
# ## 2) Example 1: a simple exchange-specific method
#
# This first JSON method has only three rules:
#
# - `Carbon dioxide` gets a CF of `1.0`
# - `Methane, fossil` gets a CF of `28.0`
# - `Dinitrogen monoxide` gets a CF of `265.0`
#
# No location condition is used yet. The main lesson is the minimal `EdgeLCIA` workflow.

# %%
example_1_data = json.loads(example_1_path.read_text())
print(json.dumps(example_1_data, indent=2))
# Out:
# {
#   "name": "Example LCIA Method",
#   "version": "1.0",
#   "description": "Example LCIA method for greenhouse gas emissions",
#   "unit": "kg CO2e",
#   "exchanges": [
#     {
#       "supplier": {
#         "name": "Carbon dioxide",
#         "operator": "startswith",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere"
#       },
#       "value": 1.0
#     },
#     {
#       "supplier": {
#         "name": "Methane, fossil",
#         "operator": "contains",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere"
#       },
#       "value": 28.0
#     },
#     {
#       "supplier": {
#         "name": "Dinitrogen monoxide",
#         "operator": "equals",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere"
#       },
#       "value": 265.0
#     }
#   ]
# }

# %% [markdown]
# The next cell selects one activity from the `bafu` database.

# %%
bd.projects.set_current("aalborg-rlcia-2026")
db = bd.Database("bafu")
activity = db.random()
activity
# Out:
# 'Yarn, cotton, at plant' (kilogram, GLO, None)

# %% [markdown]
# We now initiate the `EdgeLCIA` class like so:

# %%
lca_1 = EdgeLCIA(
    demand={activity: 1},
    filepath=str(example_1_path), # we point here to the JSON file
)

# %%
lca_1.lci() # we solve the system, as `bw2calc` usually does
lca_1.map_exchanges() # we map characterization factors with eligible edges
lca_1.evaluate_cfs() # we evaluate the factors
lca_1.lcia() # we compute H
print('Example 1 score:', lca_1.score)
# Out:
# Example 1 score: 10.980733014186004

# %% [markdown]
# We can print some statistics about the mapping of exchanges

# %%
lca_1.statistics()
# Out:
# +----------------------+------------------------+
# |       Activity       | Yarn, cotton, at plant |
# |     Method name      |  Example LCIA Method   |
# |         Unit         |        kg CO2e         |
# |      Data file       |     lcia_example_1     |
# |    CFs in method     |           3            |
# |       CFs used       |          4800          |
# |   Unique CFs used    |           3            |
# |  Exc. characterized  |          4800          |
# | Exc. uncharacterized |         78977          |
# +----------------------+------------------------+

# %% [markdown]
# And we can print a nice dataframe listing characterized (and uncharacterized) exchanges.

# %%
cf_table_1 = lca_1.generate_cf_table()
print(len(cf_table_1))
cf_table_1.head()
# Out:
# 4800
#   supplier matrix               direction        supplier name  \
# 0       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 1       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 2       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 3       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 4       biosphere  biosphere-technosphere  Dinitrogen monoxide
#
#   supplier categories                                      consumer name  \
# 0              (air,)  xxx Electricity, high voltage, production ENTS...
# 1              (air,)             xxx Electricity, high voltage, at grid
# 2              (air,)              Zeolite, slurry, 50% in H2O, at plant
# 3              (air,)                          Zeolite, powder, at plant
# 4              (air,)                                   Xylene, at plant
#
#                           consumer reference product consumer location  \
# 0  xxx Electricity, high voltage, production ENTS...           ENTSO-E
# 1             xxx Electricity, high voltage, at grid                CS
# 2              Zeolite, slurry, 50% in H2O, at plant               RER
# 3                          Zeolite, powder, at plant               RER
# 4                                   Xylene, at plant               RER
#
#          amount     CF        impact
# 0  1.277996e-09  265.0  3.386690e-07
# 1  2.461367e-13  265.0  6.522623e-11
# 2  5.615785e-12  265.0  1.488183e-09
# 3  5.543962e-11  265.0  1.469150e-08
# 4  3.488548e-09  265.0  9.244653e-07

# %%
# we can also print all of the exchange, including those that did not get a CF
# just to check things
cf_table_1 = lca_1.generate_cf_table(
    # include_unmatched=True # if True, inclues ALL exchanges, even those without a CF -- can be a bit long.
)
print(len(cf_table_1))
cf_table_1.head()
# Out:
# 4800
#   supplier matrix               direction        supplier name  \
# 0       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 1       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 2       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 3       biosphere  biosphere-technosphere  Dinitrogen monoxide
# 4       biosphere  biosphere-technosphere  Dinitrogen monoxide
#
#   supplier categories                                      consumer name  \
# 0              (air,)  xxx Electricity, high voltage, production ENTS...
# 1              (air,)             xxx Electricity, high voltage, at grid
# 2              (air,)              Zeolite, slurry, 50% in H2O, at plant
# 3              (air,)                          Zeolite, powder, at plant
# 4              (air,)                                   Xylene, at plant
#
#                           consumer reference product consumer location  \
# 0  xxx Electricity, high voltage, production ENTS...           ENTSO-E
# 1             xxx Electricity, high voltage, at grid                CS
# 2              Zeolite, slurry, 50% in H2O, at plant               RER
# 3                          Zeolite, powder, at plant               RER
# 4                                   Xylene, at plant               RER
#
#          amount     CF        impact
# 0  1.277996e-09  265.0  3.386690e-07
# 1  2.461367e-13  265.0  6.522623e-11
# 2  5.615785e-12  265.0  1.488183e-09
# 3  5.543962e-11  265.0  1.469150e-08
# 4  3.488548e-09  265.0  9.244653e-07

# %%
(
    cf_table_1.groupby('supplier name')['CF']
    .mean()
    .sort_values(ascending=False)
    .to_frame('Mean CF')
)
# Out:
#                                             Mean CF
# supplier name
# Dinitrogen monoxide                           265.0
# Methane, fossil                                28.0
# Carbon dioxide, fossil                          1.0
# Carbon dioxide, from soil or biomass stock      1.0
# Carbon dioxide, in air                          1.0
# Carbon dioxide, non-fossil                      1.0

# %% [markdown]
# Wait, there's an issue here: isn't `Carbon dioxide, in air` supposed to represent CO2 uptake? How do we fix this?

# %% [markdown]
# ## 3) Example 2: add consumer locations
#
# This second JSON method still targets `Carbon dioxide`, but now the applied CF depends on the consumer location:
#
# - `CH` gets `1.0`
# - `FR` gets `2.0`
# - `RER` gets `3.0`
#
# So the workflow starts the same way, but direct matching alone will only cover the exchanges whose locations already match those rules.

# %%
example_2_data = json.loads(example_2_path.read_text())
print(json.dumps(example_2_data, indent=2))
# Out:
# {
#   "name": "Example LCIA Method",
#   "version": "1.0",
#   "description": "Example LCIA method for greenhouse gas emissions",
#   "unit": "kg CO2e",
#   "exchanges": [
#     {
#       "supplier": {
#         "name": "Carbon dioxide",
#         "operator": "startswith",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere",
#         "location": "CH"
#       },
#       "value": 1.0
#     },
#     {
#       "supplier": {
#         "name": "Carbon dioxide",
#         "operator": "startswith",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere",
#         "location": "FR"
#       },
#       "value": 2.0
#     },
#     {
#       "supplier": {
#         "name": "Carbon dioxide",
#         "operator": "startswith",
#         "matrix": "biosphere"
#       },
#       "consumer": {
#         "matrix": "technosphere",
#         "location": "RER"
#       },
#       "value": 3.0
#     }
#   ]
# }

# %%
lca_2_direct = EdgeLCIA(
    demand={activity: 1},
    filepath=str(example_2_path),
)

# %%
lca_2_direct.lci()
lca_2_direct.map_exchanges()
lca_2_direct.evaluate_cfs()
lca_2_direct.lcia()
print('Example 2 score:', lca_2_direct.score)
# Out:
# Example 2 score: 3.9552519426086863

# %%
cf_table_2_direct = lca_2_direct.generate_cf_table()
cf_table_2_direct.head()
# Out:
#   supplier matrix               direction  \
# 0       biosphere  biosphere-technosphere
# 1       biosphere  biosphere-technosphere
# 2       biosphere  biosphere-technosphere
# 3       biosphere  biosphere-technosphere
# 4       biosphere  biosphere-technosphere
#
#                                 supplier name  \
# 0  Carbon dioxide, from soil or biomass stock
# 1  Carbon dioxide, from soil or biomass stock
# 2  Carbon dioxide, from soil or biomass stock
# 3  Carbon dioxide, from soil or biomass stock
# 4  Carbon dioxide, from soil or biomass stock
#
#                         supplier categories  \
# 0  (air, non-urban air or from high stacks)
# 1  (air, non-urban air or from high stacks)
# 2  (air, non-urban air or from high stacks)
# 3  (air, non-urban air or from high stacks)
# 4  (air, non-urban air or from high stacks)
#
#                                        consumer name  \
# 0              Zeolite, slurry, 50% in H2O, at plant
# 1                          Zeolite, powder, at plant
# 2  Wood preservative, inorganic salt, containing ...
# 3       Titanium dioxide, chloride process, at plant
# 4  Titanium dioxide at plant, sulphate process, a...
#
#                           consumer reference product consumer location  \
# 0              Zeolite, slurry, 50% in H2O, at plant               RER
# 1                          Zeolite, powder, at plant               RER
# 2  Wood preservative, inorganic salt, containing ...               RER
# 3       Titanium dioxide, chloride process, at plant               RER
# 4  Titanium dioxide at plant, sulphate process, a...               RER
#
#          amount   CF        impact
# 0  2.930338e-11  3.0  8.791015e-11
# 1  2.927624e-10  3.0  8.782873e-10
# 2  3.268964e-10  3.0  9.806893e-10
# 3  3.923037e-08  3.0  1.176911e-07
# 4  1.662240e-08  3.0  4.986719e-08

# %%
(
    cf_table_2_direct.groupby('consumer location')['CF']
    .mean()
    .sort_values(ascending=False)
    .to_frame('Mean CF')
)
# Out:
#                    Mean CF
# consumer location
# RER                    3.0
# FR                     2.0
# CH                     1.0

# %% [markdown]
# ## 4) Extend Example 2 with the spatial helper functions
#
# We now add the helper functions that expand the geographic coverage:
#
# - `map_aggregate_locations()` for aggregate regions such as `RER`
# - `map_dynamic_locations()` for dynamic regions such as `RoW`
# - `map_contained_locations()` for subregions contained in larger regions
# - `map_remaining_locations_to_global()` for the final global fallback
#
# This is the first full `edges` workflow that we will reuse later in Day 2.

# %%
lca_3 = EdgeLCIA(
    demand={activity: 1},
    filepath=str(example_2_path),
)

# %%
lca_3.lci()
lca_3.map_exchanges() # direct matches
lca_3.map_aggregate_locations() # handles aggregate locations
lca_3.map_dynamic_locations() # handles dynamic locations
lca_3.map_contained_locations() # handles contained locations
lca_3.map_remaining_locations_to_global() # handles the rest
lca_3.evaluate_cfs()
lca_3.lcia()
print('Example 2 score after helper mappings:', lca_3.score)
# Out:
# Example 2 score after helper mappings: 17.55177074207958

# %%
lca_3.statistics()
# Out:
# +----------------------+------------------------+
# |       Activity       | Yarn, cotton, at plant |
# |     Method name      |  Example LCIA Method   |
# |         Unit         |        kg CO2e         |
# |      Data file       |     lcia_example_2     |
# |    CFs in method     |           3            |
# |       CFs used       |          2114          |
# |   Unique CFs used    |           6            |
# |  Exc. characterized  |          2114          |
# | Exc. uncharacterized |         81695          |
# +----------------------+------------------------+

# %%
cf_table_3 = lca_3.generate_cf_table()
cf_table_3.head()
# Out:
#   supplier matrix               direction  \
# 0       biosphere  biosphere-technosphere
# 1       biosphere  biosphere-technosphere
# 2       biosphere  biosphere-technosphere
# 3       biosphere  biosphere-technosphere
# 4       biosphere  biosphere-technosphere
#
#                                 supplier name  \
# 0  Carbon dioxide, from soil or biomass stock
# 1  Carbon dioxide, from soil or biomass stock
# 2  Carbon dioxide, from soil or biomass stock
# 3  Carbon dioxide, from soil or biomass stock
# 4  Carbon dioxide, from soil or biomass stock
#
#                         supplier categories  \
# 0  (air, non-urban air or from high stacks)
# 1  (air, non-urban air or from high stacks)
# 2  (air, non-urban air or from high stacks)
# 3  (air, non-urban air or from high stacks)
# 4  (air, non-urban air or from high stacks)
#
#                                        consumer name  \
# 0              Zeolite, slurry, 50% in H2O, at plant
# 1                          Zeolite, powder, at plant
# 2  Wood preservative, inorganic salt, containing ...
# 3       Titanium dioxide, chloride process, at plant
# 4  Titanium dioxide at plant, sulphate process, a...
#
#                           consumer reference product consumer location  \
# 0              Zeolite, slurry, 50% in H2O, at plant               RER
# 1                          Zeolite, powder, at plant               RER
# 2  Wood preservative, inorganic salt, containing ...               RER
# 3       Titanium dioxide, chloride process, at plant               RER
# 4  Titanium dioxide at plant, sulphate process, a...               RER
#
#          amount   CF        impact
# 0  2.930338e-11  3.0  8.791015e-11
# 1  2.927624e-10  3.0  8.782873e-10
# 2  3.268964e-10  3.0  9.806893e-10
# 3  3.923037e-08  3.0  1.176911e-07
# 4  1.662240e-08  3.0  4.986719e-08

# %%
import matplotlib.pyplot as plt

(
    cf_table_3.groupby("consumer location")["CF"]
    .mean()
    .sort_values(ascending=False)
    .plot.bar(figsize=(10, 6))
)

plt.ylabel("Mean CF after helper mappings")
plt.xlabel("Consumer location")
plt.title("Mean CF by consumer location")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5) Preview the built-in method library
#
# Besides ad hoc JSON files, `edges` also ships pre-generated method definitions.

# %%
available_methods = get_available_methods()
print('Number of available methods:', len(available_methods))

for method in available_methods:
    print(method)
# Out:
# Number of available methods: 95
# ('AWARE 2.0', 'Country', 'all', 'yearly')
# ('AWARE 2.0', 'Country', 'irri', 'yearly')
# ('AWARE 2.0', 'Country', 'non', 'irri', 'yearly')
# ('AWARE 2.0', 'Country', 'unspecified', 'yearly')
# ('AWARE 2.0 prospective', 'Country', 'all', 'yearly')
# ('AWARE 2.0 prospective', 'Country', 'irri', 'yearly')
# ('AWARE 2.0 prospective', 'Country', 'non', 'irri', 'yearly')
# ('AWARE 2.0 prospective', 'Country', 'unspecified', 'yearly')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'amphibians')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'birds')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'eukaryota')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'mammals')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'plants')
# ('GLAM3', 'biodiversity', 'occupation', 'average', 'reptiles')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'amphibians')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'birds')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'eukaryota')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'mammals')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'plants')
# ('GLAM3', 'biodiversity', 'transformation', 'average', 'reptiles')
# ('GeoPolRisk', 'paired', '2024')
# ('IBIF', 'biodiversity', 'CO2', 'overall')
# ('IBIF', 'biodiversity', 'CO2', 'plants')
# ('IBIF', 'biodiversity', 'CO2', 'vertebrates')
# ('IBIF', 'biodiversity', 'LU', 'overall')
# ('IBIF', 'biodiversity', 'LU', 'plants')
# ('IBIF', 'biodiversity', 'LU', 'vertebrates')
# ('IBIF', 'biodiversity', 'NH3', 'overall')
# ('IBIF', 'biodiversity', 'NH3', 'plants')
# ('IBIF', 'biodiversity', 'NOx', 'overall')
# ('IBIF', 'biodiversity', 'NOx', 'plants')
# ('IBIF', 'biodiversity', 'all pressures', 'overall')
# ('IBIF', 'biodiversity', 'all pressures', 'plants')
# ('IBIF', 'biodiversity', 'all pressures', 'vertebrates')
# ('IBIF', 'biodiversity', 'roads', 'overall')
# ('IBIF', 'biodiversity', 'roads', 'vertebrates')
# ('ImpactWorld+ 2.1', 'Climate change, ecosystem quality, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Climate change, ecosystem quality, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Climate change, human health, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Climate change, human health, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Climate change, long term', 'midpoint')
# ('ImpactWorld+ 2.1', 'Climate change, short term', 'midpoint')
# ('ImpactWorld+ 2.1', 'Fisheries impact', 'damage')
# ('ImpactWorld+ 2.1', 'Fossil and nuclear energy use', 'midpoint')
# ('ImpactWorld+ 2.1', 'Freshwater acidification', 'damage')
# ('ImpactWorld+ 2.1', 'Freshwater acidification', 'midpoint')
# ('ImpactWorld+ 2.1', 'Freshwater ecotoxicity', 'midpoint')
# ('ImpactWorld+ 2.1', 'Freshwater ecotoxicity, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Freshwater ecotoxicity, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Freshwater eutrophication', 'damage')
# ('ImpactWorld+ 2.1', 'Freshwater eutrophication', 'midpoint')
# ('ImpactWorld+ 2.1', 'Human toxicity cancer', 'midpoint')
# ('ImpactWorld+ 2.1', 'Human toxicity cancer, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Human toxicity cancer, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Human toxicity non-cancer', 'midpoint')
# ('ImpactWorld+ 2.1', 'Human toxicity non-cancer, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Human toxicity non-cancer, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Ionizing radiations', 'midpoint')
# ('ImpactWorld+ 2.1', 'Ionizing radiations, ecosystem quality', 'damage')
# ('ImpactWorld+ 2.1', 'Ionizing radiations, human health', 'damage')
# ('ImpactWorld+ 2.1', 'Land occupation, biodiversity', 'damage')
# ('ImpactWorld+ 2.1', 'Land occupation, biodiversity', 'midpoint')
# ('ImpactWorld+ 2.1', 'Land transformation, biodiversity', 'damage')
# ('ImpactWorld+ 2.1', 'Land transformation, biodiversity', 'midpoint')
# ('ImpactWorld+ 2.1', 'Marine acidification, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Marine acidification, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Marine ecotoxicity, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Marine ecotoxicity, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Marine eutrophication', 'damage')
# ('ImpactWorld+ 2.1', 'Marine eutrophication', 'midpoint')
# ('ImpactWorld+ 2.1', 'Mineral resources use', 'midpoint')
# ('ImpactWorld+ 2.1', 'Ozone layer depletion', 'damage')
# ('ImpactWorld+ 2.1', 'Ozone layer depletion', 'midpoint')
# ('ImpactWorld+ 2.1', 'Particulate matter formation', 'damage')
# ('ImpactWorld+ 2.1', 'Particulate matter formation', 'midpoint')
# ('ImpactWorld+ 2.1', 'Photochemical ozone formation', 'midpoint')
# ('ImpactWorld+ 2.1', 'Photochemical ozone formation, ecosystem quality', 'damage')
# ('ImpactWorld+ 2.1', 'Photochemical ozone formation, human health', 'damage')
# ('ImpactWorld+ 2.1', 'Terrestrial acidification', 'damage')
# ('ImpactWorld+ 2.1', 'Terrestrial acidification', 'midpoint')
# ('ImpactWorld+ 2.1', 'Terrestrial ecotoxicity, long term', 'damage')
# ('ImpactWorld+ 2.1', 'Terrestrial ecotoxicity, short term', 'damage')
# ('ImpactWorld+ 2.1', 'Thermally polluted water', 'damage')
# ('ImpactWorld+ 2.1', 'Water availability, freshwater ecosystem', 'damage')
# ('ImpactWorld+ 2.1', 'Water availability, human health', 'damage')
# ('ImpactWorld+ 2.1', 'Water availability, terrestrial ecosystem', 'damage')
# ('ImpactWorld+ 2.1', 'Water scarcity', 'midpoint')
# ('LCC 1.0', '2023')
# ('Prospective', 'GTP100')
# ('Prospective', 'GTP50')
# ('Prospective', 'GWP100')
# ('Prospective', 'GWP20')
# ('RELICS', 'copper', 'primary')
# ('RELICS', 'copper', 'secondary')
# ('SCP', '1.0')

# %% [markdown]
# ## Recap
#
# After this notebook, you should now be able to:
#
# - connect the local `edges` example notebooks to their JSON method files
# - run the minimal `EdgeLCIA` workflow from `lci()` to `lcia()`
# - explain why regionalized methods need more than direct exchange matching
# - identify the main helper functions used to broaden spatial coverage
# - inspect the exchange-level CFs and weights used by `edges`
